# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
frequency = 5
amplitude = 1
phase = 0
duration = 1
sampling_rate = 1000

t = np.linspace(0, duration, sampling_rate * duration)

y = amplitude * np.cos(2 * np.pi * frequency * t + np.deg2rad(phase))

plt.figure(figsize=(12, 4))
plt.plot(t, y, linewidth=1)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.title(f'Cosine Wave: f = {frequency} Hz, A = {amplitude}')
plt.axhline(y=0, color='k', linewidth=0.5)
plt.xlim(0, duration)
plt.tight_layout()
plt.show()

# %%
frequency = 5
amplitude = 1
phase = 90
duration = 1
sampling_rate = 1000

t = np.linspace(0, duration, sampling_rate * duration)

y = amplitude * np.cos(2 * np.pi * frequency * t + np.deg2rad(phase))

plt.figure(figsize=(12, 4))
plt.plot(t, y, linewidth=1)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.title(f'Cosine Wave: f = {frequency} Hz, A = {amplitude}')
plt.axhline(y=0, color='k', linewidth=0.5)
plt.xlim(0, duration)
plt.tight_layout()
plt.show()
